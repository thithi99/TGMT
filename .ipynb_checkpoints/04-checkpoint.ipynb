# %%
#!pip install Pillow gọi thư viện

# %%
#import thư viện
from PIL import Image
from imgtools import *

# %%
my_path = 'C:/Users/ADMIN/Documents/TGMT_lop1/hinhanh/minion/new_minion.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=211x238>

# %%
region = (100, 75, 175, 150)
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=RGB size=75x75>

# %%
paste_position = (150, 150)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=211x238>
