# %%
# Import lớp Image
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
my_path = 'C:/Users/ADMIN/Documents/TGMT_lop1/hinhanh/minion/minion1.jpg'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=168x300>

# %%
# Kích thước ban đầu:
print(img.size)
# Out:
# (168, 300)

# %%
# Thay đổi kích thước
new_size = (5000,1000)
new_image = img.resize(new_size)
display(new_image)
# Task: lưu ảnh
# Out:
# <PIL.Image.Image image mode=RGB size=5000x1000>

# %%
# Thay đổi kích thước
thumbnail_size = (1000,1000)
img.thumbnail(thumbnail_size)
display(img)
# Task: lưu ảnh
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=168x300>
